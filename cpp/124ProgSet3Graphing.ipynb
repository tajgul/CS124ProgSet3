simulated_anneal_pp_large_iter = [5,21,34,35,6,23,147,179,39,156,65,147,32,357,12,238,14,47,238,34,69,48,19,4,270,154,85,2,20,356,49,34,78,97,88,32,248,125,246,2,12,30,12,79,28,4,61,525,37,103]

# %%
#Graph Runtime

avg_runtimes = {
    "kk": mean(kk_runtime),
    "random": mean(random_algo_runtime),
    "random_pp": mean(random_algo_pp_runtime),
    "hill_\nclimbing": mean(hill_runtime),
    "hill_\nclimbing_pp": mean(hill_pp_runtime),
    "simulated_\nanneal": mean(simulated_anneal_runtime),
    "simiulated_\nanneal_pp": mean(simulated_annleal_pp_runtime)
}
algs = list(avg_runtimes.keys())
runtimes = list(avg_runtimes.values())

fig = plt.figure(figsize = (10, 5))
 
plt.bar(algs, runtimes, color ='maroon',
        width = 0.3)
 
plt.xlabel("Heuristics")
plt.ylabel("Nanoseconds")
plt.title("Runtime of Random Heuristics")
plt.savefig("CS124ProgSet3Runtime")
plt.show()

# %%
#Graph Avg Accuracy
labels = ["random", "hill_\nclimbing", "simulated_\nanneal"]


fig, ax= plt.subplots(figsize=(10, 5))
 
ax.boxplot( [ random_algo_residuals, hill_residuals, simulated_anneal_residuals] )

 
ax.set_xlabel("Heuristics")
ax.set_ylabel("Residual")
ax.set_title("Residuals of Random Heuristics")
ax.set_xticklabels(labels)
plt.savefig("CS124ProgSet3Res")
plt.show()

# %%
#Graphing Avg Accuracy, PP
labels = ["random_pp", "hill_\nclimbing_pp",  "simiulated_\nanneal_pp" ]

fig, ax= plt.subplots(figsize=(10, 5))
 
ax.boxplot( [random_algo_pp_residuals, hill_pp_residuals, simulated_anneal_pp_residuals] )

 
ax.set_xlabel("Heuristics")
ax.set_ylabel("Residual")
ax.set_title("Residuals of Random Heuristics")
ax.set_xticklabels(labels)
plt.savefig("CS124ProgSet3Respp")
plt.show()

# %%
#Graphing PP Accuracy, with the addition of larger iterations.

labels = ["random_pp", "hill_\nclimbing_pp", "hill_climbing_pp\n_large_iter", "simiulated_\nanneal_pp",  "simiulated_anneal_pp\n_large_iter"]

fig, ax= plt.subplots(figsize=(10, 5))
 
ax.boxplot( [random_algo_pp_residuals, hill_pp_residuals, hill_pp_residuals_large_iter, simulated_anneal_pp_residuals, simulated_anneal_pp_large_iter] )

 
ax.set_xlabel("Heuristics")
ax.set_ylabel("Residual")
ax.set_title("Residuals of Random Heuristics")
ax.set_xticklabels(labels)
plt.savefig("CS124ProgSet3RuntimeResPP2")
plt.show()

# %%
#Test Starting with KK algorithm

# %%
Residuals = [random_algo_pp_residuals, hill_pp_residuals, hill_pp_residuals_large_iter, simulated_anneal_pp_residuals, simulated_anneal_pp_large_iter, kk_residuals, random_algo_residuals, hill_residuals, simulated_anneal_residuals]

# %%
for i in Residuals:
    print(mean(i))
# Out:
# 208.62
# 745.9
# 504.98
# 177
# 94.92
# 314278
# 299516408.12
# 239416774.34
# 224616022.38
